# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess(text):
    if pd.isnull(text):
        return ""
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    tokens = word_tokenize(text)
    return ' '.join([t for t in tokens if t not in stop_words])

# %%
reviews = pd.read_csv("rotten_tomatoes_critic_reviews.csv")
movies = pd.read_csv("rotten_tomatoes_movies.csv")

# %%
df = reviews.merge(movies, on='rotten_tomatoes_link')

# %%
df = df.dropna(subset=['review_content', 'review_type'])

# %%
df['cleaned_review'] = df['review_content'].apply(preprocess)
df['label'] = df['review_type'].apply(lambda x: 1 if x == 'Fresh' else 0)

# %%
X = df['cleaned_review']
y = df['label']

# %%
tfidf = TfidfVectorizer(max_features=3000)
X_tfidf = tfidf.fit_transform(X)
model = LinearSVC()
model.fit(X_tfidf, y)
# Out:
# LinearSVC()

# %%
def predict_reviews_by_movie(movie_title):
    movie_reviews = df[df['movie_title'].str.lower() == movie_title.lower()]
    if movie_reviews.empty:
        print("Movie not found or no reviews available.")
        return

    for i, row in movie_reviews.iterrows():
        processed = preprocess(row['review_content'])
        vector = tfidf.transform([processed])
        prediction = model.predict(vector)[0]
        sentiment = "Fresh" if prediction == 1 else "Rotten"
        print(f"\n🔸 Review: {row['review_content']}\n➡️ Predicted Sentiment: {sentiment}")

# %%
movie_input = input("Enter a movie name: ")
predict_reviews_by_movie(movie_input)
# Out:
# Enter a movie name: The Godfather
#
# 🔸 Review: One of the central American movies of the last 25 years, and one of very few to succed as both popular entertainment and high art.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: Examining the meaning of family, violence, love, betrayal, and loyalty just to name a few, its quality set a standard that few films have matched.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: The years have been kind to this timeless Mafia epic, which seems particularly rich now that studio blockbusters no longer demonstrate this kind of care with character, atmosphere and storytelling.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: All of the filmic arts - design, cinematography, editing, music - come together to forge what is, by any measure, one of the great movies of all time.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: Coppola was signed to direct what was thought would be a pulp gangster film, but created one of the greatest epics ever.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: The story by Mario Puzo and Francis Ford Coppola is a brilliant conjuring act, inviting us to consider the Mafia entirely on its own terms.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: So many great roles and characters in this movie and then there's that eternally haunting Nino Rota score.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: With The Godfather, Coppola got everything right, balancing art with commerce -- and turning a big-studio project into something deeply personal and resonant.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: In scene after scene ... Coppola crafted an enduring, undisputed masterpiece.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: We come to The Godfather like Kay Adams -- outsiders uncertain in our expectations - but it doesn't take long for us to be captivated by this intricate, violent world.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: Over The Godfather's three-hour running time, the story of Michael's transformation from a 'civilian' in a mob family into its hard-nosed general never flags.
# ➡️ Predicted Sentiment: Rotten
#
# 🔸 Review: While there have been changes from the novel, the film is both compelling and powerful.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: Corleone, the soft-spoken crimelord, is masterfully played by Brando in one of the most imitated performances of all time.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: The story of this movie could have taken place everywhere in the world, and that explains why the people will associate with its characters for many decades to come.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: The three-part gangster saga from Italian-American director Francis Ford Coppola is a superb trilogy of films
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: Unlike many of its imitators made during the 25 years since its release, The Godfather is a handbook on cinematic lucidity.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: As scary as it is intelligent, as funny as it is touching, The Godfather is a prime example of the way cinema should be: excellent telling of complete stories.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: A classic in its own very right, Director Francis Ford Coppola brings us, the ultimate mob movie.
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: still a riveting piece of work, a true masterpiece of the American cinema
# ➡️ Predicted Sentiment: Fresh
#
# 🔸 Review: